# %% [markdown]
# ### Import libraries

# %%
# import library

import yfinance as yf

import matplotlib as mlp
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %% [markdown]
# ### Fetching data

# %%
# setting

ticker = "NVDA"
start = '2000-01-01'
end = '2023-12-31'

# %%
# load data

df = yf.download(tickers = ticker, start = start, end = end)
df.head(10)
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2000-01-03  0.098438  0.099219  0.091927  0.097526   0.089446  300912000
# 2000-01-04  0.095833  0.096094  0.090104  0.094922   0.087058  300480000
# 2000-01-05  0.092188  0.093750  0.090495  0.091797   0.084191  188352000
# 2000-01-06  0.091797  0.091797  0.082292  0.085807   0.078698  120480000
# 2000-01-07  0.085417  0.088151  0.084115  0.087240   0.080012   71184000
# 2000-01-10  0.087500  0.093750  0.085938  0.090104   0.082639  239856000
# 2000-01-11  0.089583  0.090625  0.086458  0.086458   0.079295  148128000
# 2000-01-12  0.086458  0.086589  0.083073  0.084245   0.077265  123552000
# 2000-01-13  0.084115  0.088542  0.083073  0.087760   0.080489  132192000
# 2000-01-14  0.089063  0.095182  0.088802  0.091536   0.083952  604560000

# %%
df.tail()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2023-12-22  49.195000  49.382999  48.466999  48.830002  48.819527  252507000
# 2023-12-26  48.967999  49.599998  48.959999  49.278999  49.268425  244200000
# 2023-12-27  49.511002  49.680000  49.084999  49.417000  49.406395  233648000
# 2023-12-28  49.643002  49.883999  49.411999  49.521999  49.511375  246587000
# 2023-12-29  49.813000  49.997002  48.750999  49.521999  49.511375  389293000

# %%
df.shape
# Out:
# (6037, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6037 entries, 2000-01-03 to 2023-12-29
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       6037 non-null   float64
#  1   High       6037 non-null   float64
#  2   Low        6037 non-null   float64
#  3   Close      6037 non-null   float64
#  4   Adj Close  6037 non-null   float64
#  5   Volume     6037 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 330.1 KB

# %%
# plot

mlp.rcParams['figure.figsize'] = (8, 5)
df['Close'].plot()
plt.title(f'{ticker} from {start} to {end}')
plt.show()

# %% [markdown]
# ### Strategy

# %%
# setting

look_back = 100

# %%
# get the highest close price referred to the look back number

df['highest'] = df['Close'].rolling(look_back).max()
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2000-01-03  0.098438  0.099219  0.091927  0.097526   0.089446  300912000
# 2000-01-04  0.095833  0.096094  0.090104  0.094922   0.087058  300480000
# 2000-01-05  0.092188  0.093750  0.090495  0.091797   0.084191  188352000
# 2000-01-06  0.091797  0.091797  0.082292  0.085807   0.078698  120480000
# 2000-01-07  0.085417  0.088151  0.084115  0.087240   0.080012   71184000
#
#             highest
# Date
# 2000-01-03      NaN
# 2000-01-04      NaN
# 2000-01-05      NaN
# 2000-01-06      NaN
# 2000-01-07      NaN

# %%
df.tail()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2023-12-22  49.195000  49.382999  48.466999  48.830002  48.819527  252507000
# 2023-12-26  48.967999  49.599998  48.959999  49.278999  49.268425  244200000
# 2023-12-27  49.511002  49.680000  49.084999  49.417000  49.406395  233648000
# 2023-12-28  49.643002  49.883999  49.411999  49.521999  49.511375  246587000
# 2023-12-29  49.813000  49.997002  48.750999  49.521999  49.511375  389293000
#
#             highest
# Date
# 2023-12-22   50.409
# 2023-12-26   50.409
# 2023-12-27   50.409
# 2023-12-28   50.409
# 2023-12-29   50.409

# %%
df.head(100)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2000-01-03  0.098438  0.099219  0.091927  0.097526   0.089446  300912000
# 2000-01-04  0.095833  0.096094  0.090104  0.094922   0.087058  300480000
# 2000-01-05  0.092188  0.093750  0.090495  0.091797   0.084191  188352000
# 2000-01-06  0.091797  0.091797  0.082292  0.085807   0.078698  120480000
# 2000-01-07  0.085417  0.088151  0.084115  0.087240   0.080012   71184000
# ...              ...       ...       ...       ...        ...        ...
# 2000-05-18  0.231510  0.235286  0.213151  0.214583   0.196804  509904000
# 2000-05-19  0.208333  0.219792  0.206771  0.212760   0.195133  521184000
# 2000-05-22  0.210417  0.226563  0.191797  0.226563   0.207792  517152000
# 2000-05-23  0.220833  0.245703  0.217188  0.224740   0.206120  778560000
# 2000-05-24  0.224479  0.228125  0.192188  0.221875   0.203492  739632000
#
#              highest
# Date
# 2000-01-03       NaN
# 2000-01-04       NaN
# ...

# %%
df.head(101)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2000-01-03  0.098438  0.099219  0.091927  0.097526   0.089446  300912000
# 2000-01-04  0.095833  0.096094  0.090104  0.094922   0.087058  300480000
# 2000-01-05  0.092188  0.093750  0.090495  0.091797   0.084191  188352000
# 2000-01-06  0.091797  0.091797  0.082292  0.085807   0.078698  120480000
# 2000-01-07  0.085417  0.088151  0.084115  0.087240   0.080012   71184000
# ...              ...       ...       ...       ...        ...        ...
# 2000-05-19  0.208333  0.219792  0.206771  0.212760   0.195133  521184000
# 2000-05-22  0.210417  0.226563  0.191797  0.226563   0.207792  517152000
# 2000-05-23  0.220833  0.245703  0.217188  0.224740   0.206120  778560000
# 2000-05-24  0.224479  0.228125  0.192188  0.221875   0.203492  739632000
# 2000-05-25  0.225130  0.238542  0.216016  0.218750   0.200626  569184000
#
#              highest
# Date
# 2000-01-03       NaN
# 2000-01-04       NaN
# ...

# %%
# plot

mlp.rcParams['figure.figsize'] = (8, 5)
df[['Close', 'highest']].plot()
plt.title(f'{ticker} from {start} to {end}')
plt.legend()
plt.show()

# %%
df.iloc[90:120]
# Out:
#                 Open      High       Low     Close  Adj Close      Volume  \
# Date
# 2000-05-11  0.166667  0.174349  0.164453  0.171354   0.157157   245904000
# 2000-05-12  0.176042  0.185417  0.166146  0.166146   0.152380   187824000
# 2000-05-15  0.165365  0.180469  0.157292  0.177604   0.162889   282096000
# 2000-05-16  0.185417  0.201432  0.183333  0.195833   0.179608   366432000
# 2000-05-17  0.206250  0.238802  0.206120  0.230208   0.211135  1290624000
# 2000-05-18  0.231510  0.235286  0.213151  0.214583   0.196804   509904000
# 2000-05-19  0.208333  0.219792  0.206771  0.212760   0.195133   521184000
# 2000-05-22  0.210417  0.226563  0.191797  0.226563   0.207792   517152000
# 2000-05-23  0.220833  0.245703  0.217188  0.224740   0.206120   778560000
# 2000-05-24  0.224479  0.228125  0.192188  0.221875   0.203492   739632000
# 2000-05-25  0.225130  0.238542  0.216016  0.218750   0.200626   569184000
# 2000-05-26  0.219857  0.225911  0.206250  0.219857   0.201642   183456000
# ...

# %%
# shift row data

df['highest_shift'] = df['highest'].shift(1)
df.iloc[90:110]
# Out:
#                 Open      High       Low     Close  Adj Close      Volume  \
# Date
# 2000-05-11  0.166667  0.174349  0.164453  0.171354   0.157157   245904000
# 2000-05-12  0.176042  0.185417  0.166146  0.166146   0.152380   187824000
# 2000-05-15  0.165365  0.180469  0.157292  0.177604   0.162889   282096000
# 2000-05-16  0.185417  0.201432  0.183333  0.195833   0.179608   366432000
# 2000-05-17  0.206250  0.238802  0.206120  0.230208   0.211135  1290624000
# 2000-05-18  0.231510  0.235286  0.213151  0.214583   0.196804   509904000
# 2000-05-19  0.208333  0.219792  0.206771  0.212760   0.195133   521184000
# 2000-05-22  0.210417  0.226563  0.191797  0.226563   0.207792   517152000
# 2000-05-23  0.220833  0.245703  0.217188  0.224740   0.206120   778560000
# 2000-05-24  0.224479  0.228125  0.192188  0.221875   0.203492   739632000
# 2000-05-25  0.225130  0.238542  0.216016  0.218750   0.200626   569184000
# 2000-05-26  0.219857  0.225911  0.206250  0.219857   0.201642   183456000
# ...

# %%
# select 2 collumns to plot

mlp.rcParams['figure.figsize'] = (8, 5)
df[['Close', 'highest_shift']].loc["2022-04": "2023"].plot()
plt.title(f'{ticker} from {start} to {end}')
plt.legend()
plt.show()

# %%
# stop percentage 90% - we will sale after 10% of price dropping
stop_pct = 0.9

mlp.rcParams['figure.figsize'] = (8, 5)
df[['Close', 'highest_shift']].loc["2022-04": "2023"].plot()
(df['highest_shift'] * stop_pct).loc["2022-04": "2023"].plot(label = f'stop {(1 - stop_pct) * 100:.2f}%')
plt.title(f'{ticker} from {start} to {end}')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# add signal column

df['signal'] = 0
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2000-01-03  0.098438  0.099219  0.091927  0.097526   0.089446  300912000
# 2000-01-04  0.095833  0.096094  0.090104  0.094922   0.087058  300480000
# 2000-01-05  0.092188  0.093750  0.090495  0.091797   0.084191  188352000
# 2000-01-06  0.091797  0.091797  0.082292  0.085807   0.078698  120480000
# 2000-01-07  0.085417  0.088151  0.084115  0.087240   0.080012   71184000
#
#             highest  highest_shift  signal
# Date
# 2000-01-03      NaN            NaN       0
# 2000-01-04      NaN            NaN       0
# 2000-01-05      NaN            NaN       0
# 2000-01-06      NaN            NaN       0
# 2000-01-07      NaN            NaN       0

# %%
df.tail()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume  \
# Date
# 2023-12-22  49.195000  49.382999  48.466999  48.830002  48.819527  252507000
# 2023-12-26  48.967999  49.599998  48.959999  49.278999  49.268425  244200000
# 2023-12-27  49.511002  49.680000  49.084999  49.417000  49.406395  233648000
# 2023-12-28  49.643002  49.883999  49.411999  49.521999  49.511375  246587000
# 2023-12-29  49.813000  49.997002  48.750999  49.521999  49.511375  389293000
#
#             highest  highest_shift  signal
# Date
# 2023-12-22   50.409         50.409       0
# 2023-12-26   50.409         50.409       0
# 2023-12-27   50.409         50.409       0
# 2023-12-28   50.409         50.409       0
# 2023-12-29   50.409         50.409       0

# %%
for i in range(look_back + 1, len(df)): # look_back + 1 (select 2 days ago High)
    
    # Price will be equal to today price if yesterday price equal or less than today price
    if (df["Close"].iloc[i] > df["highest_shift"].iloc[i]) & (df["Close"].iloc[i-1] <= df["highest_shift"].iloc[i-1]): 
        df["signal"].iloc[i] = 1 # if > previous High price then buy by checking yesterday close price if it less or equal to then we know that it's breaking
    # If today price is less than stop loss 10% then 0
    elif (df["Close"].iloc[i] < df["highest_shift"].iloc[i] * stop_pct):
        df["signal"].iloc[i] = 0 
    # If price not in 2 above conditions, lets maintain signal
    else:
         df["signal"].iloc[i] =  df["signal"].iloc[i-1]        
            
df.head()
# Out:
# /var/folders/0z/2gy2pkss67v3rwygb64_tfvm0000gn/T/ipykernel_14623/2166522083.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["signal"].iloc[i] = 0
# /var/folders/0z/2gy2pkss67v3rwygb64_tfvm0000gn/T/ipykernel_14623/2166522083.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["signal"].iloc[i] =  df["signal"].iloc[i-1]
# /var/folders/0z/2gy2pkss67v3rwygb64_tfvm0000gn/T/ipykernel_14623/2166522083.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df[['signal']].plot()
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
df[['signal']].plot(figsize = (20, 5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
# calculate returns

df['returns'] = df['Close'].pct_change()
df.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2000-01-03  0.098438  0.099219  0.091927  0.097526   0.089446  300912000
# 2000-01-04  0.095833  0.096094  0.090104  0.094922   0.087058  300480000
# 2000-01-05  0.092188  0.093750  0.090495  0.091797   0.084191  188352000
# 2000-01-06  0.091797  0.091797  0.082292  0.085807   0.078698  120480000
# 2000-01-07  0.085417  0.088151  0.084115  0.087240   0.080012   71184000
#
#             highest  highest_shift  signal   returns
# Date
# 2000-01-03      NaN            NaN       0       NaN
# 2000-01-04      NaN            NaN       0 -0.026701
# 2000-01-05      NaN            NaN       0 -0.032922
# 2000-01-06      NaN            NaN       0 -0.065253
# 2000-01-07      NaN            NaN       0  0.016700

# %%
# calculate simple return

df['strat'] = df['signal'].shift(1) * df['returns']
df.head(10)
# Out:
#                 Open      High       Low     Close  Adj Close     Volume  \
# Date
# 2000-01-03  0.098438  0.099219  0.091927  0.097526   0.089446  300912000
# 2000-01-04  0.095833  0.096094  0.090104  0.094922   0.087058  300480000
# 2000-01-05  0.092188  0.093750  0.090495  0.091797   0.084191  188352000
# 2000-01-06  0.091797  0.091797  0.082292  0.085807   0.078698  120480000
# 2000-01-07  0.085417  0.088151  0.084115  0.087240   0.080012   71184000
# 2000-01-10  0.087500  0.093750  0.085938  0.090104   0.082639  239856000
# 2000-01-11  0.089583  0.090625  0.086458  0.086458   0.079295  148128000
# 2000-01-12  0.086458  0.086589  0.083073  0.084245   0.077265  123552000
# 2000-01-13  0.084115  0.088542  0.083073  0.087760   0.080489  132192000
# 2000-01-14  0.089063  0.095182  0.088802  0.091536   0.083952  604560000
#
#             highest  highest_shift  signal   returns  strat
# Date
# 2000-01-03      NaN            NaN       0       NaN    NaN
# ...

# %%
# calculate the return of buy and hold for the last day [-1]

bnh = ((df['returns'] + 1).cumprod()[-1]-1) * 100
strat = ((df['strat'] + 1).cumprod()[-1]-1) * 100
bnh, strat
# Out:
# (50678.25389362869, 8685.691793239668)

# %%
# plot 

mlp.rcParams['figure.figsize'] = (20, 5)
df[['Close', 'highest_shift']].plot()
(df["highest_shift"] * stop_pct).plot(label = f'running stop {(1 - stop_pct)*100:.2f} %')
plt.title(f'{ticker} from {start} to {end}')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
df['signal'].diff()
# Out:
# Date
# 2000-01-03    NaN
# 2000-01-04    0.0
# 2000-01-05    0.0
# 2000-01-06    0.0
# 2000-01-07    0.0
#              ...
# 2023-12-22    0.0
# 2023-12-26    0.0
# 2023-12-27    0.0
# 2023-12-28    0.0
# 2023-12-29    0.0
# Name: signal, Length: 6037, dtype: float64

# %%
# Sale: -1, Buy: 1, and No action: 0

df['signal'].diff().unique()
# Out:
# array([nan,  0.,  1., -1.])

# %%
# get the buy date

df[df['signal'].diff() == 1].index
# Out:
# DatetimeIndex(['2000-06-16', '2001-04-17', '2001-05-01', '2001-06-06',
#                '2001-11-06', '2003-05-02', '2003-12-23', '2004-03-30',
#                '2004-11-23', '2005-02-02', '2005-08-12', '2005-11-17',
#                '2006-10-04', '2007-06-05', '2009-03-17', '2009-07-23',
#                '2009-12-16', '2010-11-03', '2011-02-17', '2011-12-01',
#                '2012-02-08', '2013-04-24', '2014-09-03', '2014-11-04',
#                '2015-08-10', '2015-09-30', '2016-03-18', '2017-02-07',
#                '2017-05-10', '2017-07-12', '2018-01-08', '2018-02-20',
#                '2018-05-09', '2018-08-24', '2019-10-11', '2020-05-11',
#                '2020-11-06', '2021-02-10', '2021-04-13', '2021-05-28',
#                '2021-08-20', '2021-10-25', '2023-01-23', '2023-02-23',
#                '2023-08-29', '2023-11-14'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
len(df[df['signal'].diff() == 1].index)
# Out:
# 46

# %%
df[["Close", "highest_shift"]].plot(figsize = (20, 5))
(df["highest_shift"] * stop_pct).plot(label = f'running stop {(1 - stop_pct)*100:.2f} %')

plt.plot(df[df["signal"].diff() == 1].index, df[df["signal"].diff() == 1]['Close'], '^', markersize = 15, color = 'green') # -1: sale, 1: buy, 0: no action
plt.plot(df[df["signal"].diff() == -1].index, df[df["signal"].diff() == -1]['Close'], 'v', markersize = 15, color = 'red')
plt.title(f'{ticker} from {start} to {end}')
plt.legend()
plt.show()

# %%
# Let's zoom in

df[["Close", "highest_shift"]].loc["2020-07":"2023-12"].plot(figsize = (20, 5))
(df["highest_shift"] * stop_pct).loc["2020-07":"2023-12"].plot(label = f"running stop {(1 - stop_pct) * 100:.1f} %")

plt.plot(df[df["signal"].diff() == 1].loc["2020-07":"2023-12"].index, df[df["signal"].diff() == 1].loc["2020-07":"2023-12"]['Close'], '^', markersize = 15, color = 'green')
plt.plot(df[df["signal"].diff() == -1].loc["2020-07":"2023-12"].index, df[df["signal"].diff() == -1].loc["2020-07":"2023-12"]['Close'], 'v', markersize = 15, color = 'red')
plt.title(f'{ticker} from {start} to {end}')
plt.legend()
plt.show()

# %%
(df["returns"] + 1).cumprod().plot(label = f"bnh: {bnh:.2f}%", alpha = 0.8, linewidth = 3, figsize=(20, 5))
(df["strat"] + 1).cumprod().plot(label = f"strat: {strat:.2f}%", alpha = 0.8, linewidth = 3)
plt.title(f"Strategy vs {ticker} returns")
plt.legend()
plt.plot()
# Out:
# []
