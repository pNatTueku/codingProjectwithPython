# %% [markdown]
# ### Import libraries

# %%
import pandas as pd 
import numpy as np 
import yfinance as yf 

import matplotlib as mlp
import matplotlib.pyplot as plt 
# %matplotlib inline
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Load stock data

# %%
# stock list

stock_list = ['AAPL', 'NVDA', 'MSFT', 'WDC']
len(stock_list)
# Out:
# 4

# %%
type(stock_list)
# Out:
# list

# %%
pd.Series(stock_list)
# Out:
# 0    AAPL
# 1    NVDA
# 2    MSFT
# 3     WDC
# dtype: object

# %%
type(pd.Series(stock_list))
# Out:
# pandas.core.series.Series

# %%
# setting
start = '2000-01-01'
end = '2023-12-31'
interval = '1wk' # get data by weekly

np.random.seed(42)
N = 3

sample_stock_list = pd.Series(stock_list).sample(N).to_list()
sample_stock_list
# Out:
# ['NVDA', 'WDC', 'AAPL']

# %%
# fetch data

df = yf.download(sample_stock_list, start = start, interval = interval, end = end)
df.head(10)
# Out:
# [*********************100%%**********************]  3 of 3 completed
#            Adj Close                         Close                    \
#                 AAPL      NVDA       WDC      AAPL      NVDA     WDC
# Date
# 2000-01-01  0.749401  0.080012  4.515738  0.888393  0.087240  5.6250
# 2000-01-08  0.756462  0.083952  3.612591  0.896763  0.091536  4.5000
# 2000-01-15  0.838370  0.085505  4.114340  0.993862  0.093229  5.1250
# 2000-01-22  0.765406  0.071414  4.013990  0.907366  0.077865  5.0000
# 2000-01-29  0.813421  0.077504  4.064164  0.964286  0.084505  5.0625
# 2000-02-05  0.819069  0.095537  3.963816  0.970982  0.104167  4.9375
# 2000-02-12  0.837899  0.128736  3.462066  0.993304  0.140365  4.3125
# 2000-02-19  0.831308  0.116913  3.161017  0.985491  0.127474  3.9375
# 2000-02-26  0.964054  0.112494  3.612591  1.142857  0.122656  4.5000
# 2000-03-04  0.947108  0.225465  4.164515  1.122768  0.245833  5.1875
#
# ...

# %%
df.shape
# Out:
# (1252, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1252 entries, 2000-01-01 to 2023-12-23
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  1252 non-null   float64
#  1   (Adj Close, NVDA)  1252 non-null   float64
#  2   (Adj Close, WDC)   1252 non-null   float64
#  3   (Close, AAPL)      1252 non-null   float64
#  4   (Close, NVDA)      1252 non-null   float64
#  5   (Close, WDC)       1252 non-null   float64
#  6   (High, AAPL)       1252 non-null   float64
#  7   (High, NVDA)       1252 non-null   float64
#  8   (High, WDC)        1252 non-null   float64
#  9   (Low, AAPL)        1252 non-null   float64
#  10  (Low, NVDA)        1252 non-null   float64
#  11  (Low, WDC)         1252 non-null   float64
#  12  (Open, AAPL)       1252 non-null   float64
#  13  (Open, NVDA)       1252 non-null   float64
#  14  (Open, WDC)        1252 non-null   float64
# ...

# %%
df = df['Adj Close']
df.head(10)
# Out:
#                 AAPL      NVDA       WDC
# Date
# 2000-01-01  0.749401  0.080012  4.515738
# 2000-01-08  0.756462  0.083952  3.612591
# 2000-01-15  0.838370  0.085505  4.114340
# 2000-01-22  0.765406  0.071414  4.013990
# 2000-01-29  0.813421  0.077504  4.064164
# 2000-02-05  0.819069  0.095537  3.963816
# 2000-02-12  0.837899  0.128736  3.462066
# 2000-02-19  0.831308  0.116913  3.161017
# 2000-02-26  0.964054  0.112494  3.612591
# 2000-03-04  0.947108  0.225465  4.164515

# %%
# plot

mlp.rcParams['figure.figsize'] = (10, 5)
df.plot()
plt.title(f'Sample stock from {start} to {end}')
plt.xlabel('Price')
plt.ylabel('Date')
plt.show()

# %%
# calculate simple return

for ticker in sample_stock_list:
    df[f'{ticker}_returns'] = df[f'{ticker}'].pct_change()

df
# Out:
#                   AAPL       NVDA        WDC  NVDA_returns  WDC_returns  \
# Date
# 2000-01-01    0.749401   0.080012   4.515738           NaN          NaN
# 2000-01-08    0.756462   0.083952   3.612591      0.049243    -0.200000
# 2000-01-15    0.838370   0.085505   4.114340      0.018496     0.138889
# 2000-01-22    0.765406   0.071414   4.013990     -0.164798    -0.024390
# 2000-01-29    0.813421   0.077504   4.064164      0.085276     0.012500
# ...                ...        ...        ...           ...          ...
# 2023-11-25  190.307693  46.750854  48.389999     -0.021161     0.038412
# 2023-12-02  194.755875  47.491631  47.860001      0.015845    -0.010953
# 2023-12-09  196.606827  48.879509  50.680000      0.029224     0.058922
# 2023-12-16  192.656189  48.819527  52.660000     -0.001227     0.039069
# 2023-12-23  191.591385  49.511375  52.369999      0.014172    -0.005507
#
#             AAPL_returns
# Date
# 2000-01-01           NaN
# 2000-01-08      0.009421
# ...
